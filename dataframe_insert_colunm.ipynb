# %%
import pandas as pd

df = pd.read_excel("excel/Stock.xlsx",index_col="Name")

# %%
df["delivery"]=100
df
# Out:
#                              Category    Price  Amount  delivery
# Name
# เมาส์              อุปกรณ์คอมพิวเตอร์    900.0    10.0       100
# ปากกา                 อุปกรณ์การเรียน    200.0     5.0       100
# โคมไฟ                เครื่องใช้ในบ้าน   1200.0     7.0       100
# ไมโครโฟน              เครื่องใช้ไฟฟ้า    750.0     1.0       100
# เครื่องซักผ้า         เครื่องใช้ไฟฟ้า   3500.0     0.0       100
# เสื้อยืดคอกลม                เสื้อผ้า    500.0     2.0       100
# กางเกงยีนต์                  เสื้อผ้า    999.0     8.0       100
# ตุ๊กตาหมีพูห์                 ของเล่น    950.0     5.0       100
# โซฟา                     เฟอร์นิเจอร์   5000.0     5.0       100
# จาน                       เครื่องครัว    250.0     4.0       100
# ทีวี                  เครื่องใช้ไฟฟ้า  15000.0     7.0       100
# ยางลบ                 อุปกรณ์การเรียน     20.0     5.0       100
# External HardDisk  อุปกรณ์คอมพิวเตอร์   2500.0     7.0       100
# ...

# %%
df["total"]=df["Price"]+df["delivery"]
df
# Out:
#                              Category    Price  Amount  delivery    total
# Name
# เมาส์              อุปกรณ์คอมพิวเตอร์    900.0    10.0       100   1000.0
# ปากกา                 อุปกรณ์การเรียน    200.0     5.0       100    300.0
# โคมไฟ                เครื่องใช้ในบ้าน   1200.0     7.0       100   1300.0
# ไมโครโฟน              เครื่องใช้ไฟฟ้า    750.0     1.0       100    850.0
# เครื่องซักผ้า         เครื่องใช้ไฟฟ้า   3500.0     0.0       100   3600.0
# เสื้อยืดคอกลม                เสื้อผ้า    500.0     2.0       100    600.0
# กางเกงยีนต์                  เสื้อผ้า    999.0     8.0       100   1099.0
# ตุ๊กตาหมีพูห์                 ของเล่น    950.0     5.0       100   1050.0
# โซฟา                     เฟอร์นิเจอร์   5000.0     5.0       100   5100.0
# จาน                       เครื่องครัว    250.0     4.0       100    350.0
# ทีวี                  เครื่องใช้ไฟฟ้า  15000.0     7.0       100  15100.0
# ยางลบ                 อุปกรณ์การเรียน     20.0     5.0       100    120.0
# ...
